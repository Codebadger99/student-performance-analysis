# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

sns.set_style('darkgrid')

sns.set_palette('dark')

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')

df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
df.isna().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df[df.isna().any(axis=1)].head(10)
# Out:
#      Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 33              14          60                 High              Medium
# 127             17          97               Medium              Medium
# 240             15          87                  Low              Medium
# 275             23          82                  Low              Medium
# 316             24          90                  Low                 Low
# 359             15          64               Medium              Medium
# 380             15          70                 High              Medium
# 396             10          80                 High              Medium
# 402             20          66                 High                High
# 408             21          65                 High                High
#
#     Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 33                          No            5               50           Medium
# ...

# %%
nan_cols = ['Teacher_Quality', 'Parental_Education_Level', 'Distance_from_Home']

for cols in nan_cols:
    df[cols] = df[cols].fillna(df[cols].mode()[0])

# %%
df.isna().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(15, 5))

sns.boxplot(df)

plt.show()

# %%
outlier_cols = ['Hours_Studied', 'Tutoring_Sessions', 'Exam_Score']

for cols in outlier_cols:
    Q1 = df[cols].quantile(0.25)
    Q3 = df[cols].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    higher = Q3 + 1.5 * IQR

    df[cols] = df[cols].clip(lower, higher)

# %%
plt.figure(figsize=(15, 5))

sns.boxplot(df)

plt.title("After clipping outliers")

plt.show()

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.971848    79.977448      7.02906        75.070531
# std         5.951016    11.547475      1.46812        14.399784
# min         4.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        36.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.436355           2.967610    67.127138
# std             1.096018           1.031231     3.372908
# min             0.000000           0.000000    59.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
tier_map = {"Low": 1, "Medium": 2, "High": 3}
internet_map = {"No": 1, "Yes": 3}

# def map_tutoring(sessions):
#   if sessions == 0:
#     return 1
#   elif sessions <= 2:
#     return 2
#   else:
#     return 3

df["PI_mapped"] = df["Parental_Involvement"].map(tier_map)
df["AR_mapped"] = df["Access_to_Resources"].map(tier_map)
df["IA_mapped"] = df["Internet_Access"].map(internet_map)
# df["Tut_mapped"] = df["Tutoring_Sessions"].apply(map_tutoring)

# df["Support_System_Score"] = (
#     df["PI_mapped"] + df["AR_mapped"] + df["IA_mapped"] + df["Tut_mapped"]
# )
  
# df["Engagement_score"] = df['Hours_Studied'] * (df['Attendance'] / 100)

# %%
def map_instensity(hours):
    if hours < 15:
        return "Light Study"
    elif 15 <= hours <= 25:
        return "Moderate"
    else:
        return "Intense"



df['Study_Intensity'] = df['Hours_Studied'].apply(map_instensity)

# %%
def map_sleep_hours(hours):
    if hours < 6:
        return "Insufficient"
    elif 6 <= hours <= 8:
        return "Recommended"
    else:
        return "High"



df['Sleep_Adequacy'] = df['Sleep_Hours'].apply(map_sleep_hours)

# %%
# df["Exam_Delta"] = df["Exam_Score"] - df["Previous_Scores"]


Q4 = df["Exam_Score"].quantile(0.25)
Q6 = df["Exam_Score"].quantile(0.75)


def classify_performance(score):
  if score <= Q4:
    return "Underperformers"
  elif score <= Q6:
    return "Average"
  else:
    return "Top Performers"


df["Performance_Tier"] = df["Exam_Score"].apply(classify_performance)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions  ... Parental_Education_Level  \
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")

plt.show()
